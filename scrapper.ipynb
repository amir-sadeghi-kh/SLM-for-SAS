# %%
url = "https://go.documentation.sas.com/doc/en/pgmsascdc/9.4_3.4/ormpug/ormpug_optmodel_examples01.htm"

# %%
# Step 1: Scrape Web Pages
def fetch_page(url):
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful
    print()
    return response.text

def extract_sas_code(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    # Example: Assuming SAS code is inside <pre> tags with class "xisDoc-code"
    code_blocks = soup.find_all('pre', class_='xisDoc-code')
    codes = [block.get_text() for block in code_blocks]
    print(codes)
    return codes

extract_sas_code()
# Out:
# <function __main__.fetch_page(url)>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import json
import time

# Configure Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no GUI)
service = Service('/path/to/chromedriver')  # Update path to your chromedriver
driver = webdriver.Chrome(service=service, options=chrome_options)

# Step 1: Scrape Web Pages
def fetch_page(url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to fully load
    return driver.page_source
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/personal-projects/SLM-for-SAS/.venv/lib/python3.12/site-packages/selenium/webdriver/common/driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[8], line 13
#      11 chrome_options.add_argument("--headless")  # Run in headless mode (no GUI)
#      12 service = Service('/path/to/chromedriver')  # Update path to your chromedriver
# ---> 13 driver = webdriver.Chrome(service=service, options=chrome_options)
# ...

# %%
! pip install playwright
# Out:
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 12.0 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_page(url):
    async with async_playwright() as p:
        # Launch browser
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Open the webpage
        await page.goto(url, wait_until='networkidle')

        # Extract the page content
        page_content = await page.content()
        print(page_content)

        # Close the browser
        await browser.close()

# URL of the page to scrape
url = "https://go.documentation.sas.com/doc/en/pgmsascdc/9.4_3.4/ormpug/ormpug_optmodel_examples01.htm"

# Run the async function
asyncio.run(scrape_page(url))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 24
#      21 url = "https://go.documentation.sas.com/doc/en/pgmsascdc/9.4_3.4/ormpug/ormpug_optmodel_examples01.htm"
#      23 # Run the async function
# ---> 24 asyncio.run(scrape_page(url))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# ...
